# %%
code = "osxwkvosxb"

# %%
alphabet = "abcdefghijklmnopqrstuvwxyz"

# %%
counts = {}
for item in alphabet:
    counts[item] = code.count(item)

# %%
counts
# Out:
# {'a': 0,
#  'b': 1,
#  'c': 0,
#  'd': 0,
#  'e': 0,
#  'f': 0,
#  'g': 0,
#  'h': 0,
#  'i': 0,
#  'j': 0,
#  'k': 1,
#  'l': 0,
#  'm': 0,
#  'n': 0,
#  'o': 2,
#  'p': 0,
#  'q': 0,
#  'r': 0,
#  's': 2,
#  't': 0,
#  'u': 0,
#  'v': 1,
#  'w': 1,
#  'x': 2,
#  'y': 0,
#  'z': 0}

# %%
sort_counts = sorted(counts.items(), key=lambda x: x[1], reverse=True)

# %%
sort_counts
# Out:
# [('o', 2),
#  ('s', 2),
#  ('x', 2),
#  ('b', 1),
#  ('k', 1),
#  ('v', 1),
#  ('w', 1),
#  ('a', 0),
#  ('c', 0),
#  ('d', 0),
#  ('e', 0),
#  ('f', 0),
#  ('g', 0),
#  ('h', 0),
#  ('i', 0),
#  ('j', 0),
#  ('l', 0),
#  ('m', 0),
#  ('n', 0),
#  ('p', 0),
#  ('q', 0),
#  ('r', 0),
#  ('t', 0),
#  ('u', 0),
#  ('y', 0),
#  ('z', 0)]

# %%
max_value = sort_counts[0][1]
# Out:
# 2

# %%
def get_index(char):
    for index, item in enumerate(alphabet):
        if item == char:
            return index

# %%
many_char = list("enisratdhulcgmobwfkzpvjyxq")
len(many_char)
# Out:
# 26

# %%
max_values_length = len([x for x in sort_counts if x[1] == max_value])
max_values_length
# Out:
# 3

# %%
many_char_max = list(zip(all_with_max, many_char))
many_char_max
# Out:
# [(('o', 2), 'e'), (('s', 2), 'n'), (('x', 2), 'i')]

# %%
counts_char = list(zip(sort_counts, many_char))
counts_char
# Out:
# [(('o', 2), 'e'),
#  (('s', 2), 'n'),
#  (('x', 2), 'i'),
#  (('b', 1), 's'),
#  (('k', 1), 'r'),
#  (('v', 1), 'a'),
#  (('w', 1), 't'),
#  (('a', 0), 'd'),
#  (('c', 0), 'h'),
#  (('d', 0), 'u'),
#  (('e', 0), 'l'),
#  (('f', 0), 'c'),
#  (('g', 0), 'g'),
#  (('h', 0), 'm'),
#  (('i', 0), 'o'),
#  (('j', 0), 'b'),
#  (('l', 0), 'w'),
#  (('m', 0), 'f'),
#  (('n', 0), 'k'),
#  (('p', 0), 'z'),
#  (('q', 0), 'p'),
#  (('r', 0), 'v'),
#  (('t', 0), 'j'),
#  (('u', 0), 'y'),
#  (('y', 0), 'x'),
#  (('z', 0), 'q')]

# %% [markdown]
# ### New Begin

# %%
code = "osxwkvosxb"
alphabet = "abcdefghijklmnopqrstuvwxyz"
many_char = list("enisratdhulcgmobwfkzpvjyxq")

# %%
class letter:
    def __init__(self, char, count):
        self.char = char
        self.count = count
        self.possibilities = []
        self.key_possibilities = []
    def add_possibilities(self, others):
        for i in range(others):
            self.possibilities.append(many_char[i])
    def add_key_possibilities(self):
        for i in self.possibilities:
            dif = self.get_index(self.char) - self.get_index(i)
            self.key_possibilities.append(dif % len(alphabet))
    def get_index(self, char):
        for index, item in enumerate(alphabet):
            if item == char:
                return index

# %%
counts = {}
for item in alphabet:
    counts[item] = code.count(item)
sort_counts = sorted(counts.items(), key=lambda x: x[1], reverse=True)
sort_counts
# Out:
# [('o', 2),
#  ('s', 2),
#  ('x', 2),
#  ('b', 1),
#  ('k', 1),
#  ('v', 1),
#  ('w', 1),
#  ('a', 0),
#  ('c', 0),
#  ('d', 0),
#  ('e', 0),
#  ('f', 0),
#  ('g', 0),
#  ('h', 0),
#  ('i', 0),
#  ('j', 0),
#  ('l', 0),
#  ('m', 0),
#  ('n', 0),
#  ('p', 0),
#  ('q', 0),
#  ('r', 0),
#  ('t', 0),
#  ('u', 0),
#  ('y', 0),
#  ('z', 0)]

# %%
letters = []
finished = []
for i in sort_counts:
    letters.append(letter(i[0], i[1]))

# %%
letters[0].char
# Out:
# 'o'

# %% [markdown]
# Looping Part

# %%
max_value = sort_counts[0][1]
max_values_length = len([x for x in sort_counts if x[1] == max_value])
for i in range(max_values_length):
    sort_counts.pop(0)

# %%
sort_counts
# Out:
# []

# %%
for i in range(max_values_length):
    letters[0].add_possibilities(max_values_length)
    finished.append(letters[0])
    letters.pop(0)
# Has to be afterwards
for i in range(max_values_length):
    many_char.pop(0)

# %%
finished
# Out:
# [<__main__.letter at 0x182e5dc1248>,
#  <__main__.letter at 0x182e5dc1a48>,
#  <__main__.letter at 0x182e5dc10c8>,
#  <__main__.letter at 0x182e5dc1848>,
#  <__main__.letter at 0x182e5dc1508>,
#  <__main__.letter at 0x182e5dc1b48>,
#  <__main__.letter at 0x182e5dc1408>,
#  <__main__.letter at 0x182e5dc13c8>,
#  <__main__.letter at 0x182e5dc1608>,
#  <__main__.letter at 0x182e5dc1288>,
#  <__main__.letter at 0x182e5dc1688>,
#  <__main__.letter at 0x182e5dc1888>,
#  <__main__.letter at 0x182e5dc11c8>,
#  <__main__.letter at 0x182e5dc19c8>,
#  <__main__.letter at 0x182e5dc1488>,
#  <__main__.letter at 0x182e5dc12c8>,
#  <__main__.letter at 0x182e5dc1208>,
#  <__main__.letter at 0x182e5dc1948>,
#  <__main__.letter at 0x182e5dc1e48>,
#  <__main__.letter at 0x182e5dc1d48>,
#  <__main__.letter at 0x182e5dae548>,
#  <__main__.letter at 0x182e5daea08>,
#  <__main__.letter at 0x182e5dae1c8>,
#  <__main__.letter at 0x182e5daeb08>,
#  <__main__.letter at 0x182e5daecc8>,
#  <__main__.letter at 0x182e5dae9c8>]

# %%
finished[-1].possibilities
# Out:
# ['d',
#  'h',
#  'u',
#  'l',
#  'c',
#  'g',
#  'm',
#  'o',
#  'b',
#  'w',
#  'f',
#  'k',
#  'z',
#  'p',
#  'v',
#  'j',
#  'y',
#  'x',
#  'q']

# %% [markdown]
# Loop ended

# %%
for i in finished:
    i.add_key_possibilities()

# %%
finished[0].key_possibilities
# Out:
# [10, 1, 6]

# %%
keys = []
for i in finished:
    for e in i.key_possibilities:
        keys.append(e)

# %%
keys
# Out:
# [10,
#  1,
#  6,
#  14,
#  5,
#  10,
#  19,
#  10,
#  15,
#  9,
#  10,
#  1,
#  8,
#  18,
#  19,
#  10,
#  17,
#  3,
#  4,
#  21,
#  2,
#  4,
#  5,
#  22,
#  3,
#  23,
#  19,
#  6,
#  15,
#  24,
#  20,
#  14,
#  12,
#  25,
#  4,
#  21,
#  16,
#  1,
#  11,
#  5,
#  17,
#  2,
#  3,
#  10,
#  25,
#  21,
#  8,
#  17,
#  0,
#  22,
#  16,
#  14,
#  1,
#  6,
#  23,
#  18,
#  3,
#  13,
#  7,
#  19,
#  4,
#  5,
#  12,
#  0,
#  22,
#  9,
#  18,
#  1,
#  23,
#  17,
#  15,
#  2,
#  7,
#  24,
#  19,
#  4,
#  14,
#  8,
#  20,
#  5,
#  6,
#  13,
#  1,
#  23,
#  10,
#  19,
#  2,
#  24,
#  18,
#  16,
#  3,
#  8,
#  25,
#  20,
#  5,
#  15,
#  9,
#  21,
#  6,
#  7,
#  14,
#  2,
#  24,
#  11,
#  20,
#  3,
#  25,
#  19,
#  17,
#  4,
#  9,
#  0,
#  21,
#  6,
#  16,
#  10,
#  22,
#  7,
#  8,
#  15,
#  3,
#  25,
#  12,
#  21,
#  4,
#  0,
#  20,
#  18,
#  5,
#  10,
#  1,
#  22,
#  7,
#  17,
#  11,
#  23,
#  8,
#  9,
#  16,
#  4,
#  0,
#  13,
#  22,
#  5,
#  1,
#  21,
#  19,
#  6,
#  11,
#  2,
#  23,
#  8,
#  18,
#  12,
#  24,
#  9,
#  10,
#  17,
#  5,
#  1,
#  14,
#  23,
#  6,
#  2,
#  22,
#  20,
#  7,
#  12,
#  3,
#  24,
#  9,
#  19,
#  13,
#  25,
#  10,
#  11,
#  18,
#  6,
#  2,
#  15,
#  24,
#  7,
#  3,
#  23,
#  21,
#  8,
#  13,
#  4,
#  25,
#  10,
#  20,
#  14,
#  0,
#  11,
#  12,
#  19,
#  8,
#  4,
#  17,
#  0,
#  9,
#  5,
#  25,
#  23,
#  10,
#  15,
#  6,
#  1,
#  12,
#  22,
#  16,
#  2,
#  13,
#  14,
#  21,
#  9,
#  5,
#  18,
#  1,
#  10,
#  6,
#  0,
#  24,
#  11,
#  16,
#  7,
#  2,
#  13,
#  23,
#  17,
#  3,
#  14,
#  15,
#  22,
#  10,
#  6,
#  19,
#  2,
#  11,
#  7,
#  1,
#  25,
#  12,
#  17,
#  8,
#  3,
#  14,
#  24,
#  18,
#  4,
#  15,
#  16,
#  23,
#  12,
#  8,
#  21,
#  4,
#  13,
#  9,
#  3,
#  1,
#  14,
#  19,
#  10,
#  5,
#  16,
#  0,
#  20,
#  6,
#  17,
#  18,
#  25,
#  13,
#  9,
#  22,
#  5,
#  14,
#  10,
#  4,
#  2,
#  15,
#  20,
#  11,
#  6,
#  17,
#  1,
#  21,
#  7,
#  18,
#  19,
#  0,
#  14,
#  10,
#  23,
#  6,
#  15,
#  11,
#  5,
#  3,
#  16,
#  21,
#  12,
#  7,
#  18,
#  2,
#  22,
#  8,
#  19,
#  20,
#  1,
#  16,
#  12,
#  25,
#  8,
#  17,
#  13,
#  7,
#  5,
#  18,
#  23,
#  14,
#  9,
#  20,
#  4,
#  24,
#  10,
#  21,
#  22,
#  3,
#  17,
#  13,
#  0,
#  9,
#  18,
#  14,
#  8,
#  6,
#  19,
#  24,
#  15,
#  10,
#  21,
#  5,
#  25,
#  11,
#  22,
#  23,
#  4,
#  21,
#  17,
#  4,
#  13,
#  22,
#  18,
#  12,
#  10,
#  23,
#  2,
#  19,
#  14,
#  25,
#  9,
#  3,
#  15,
#  0,
#  1,
#  8,
#  22,
#  18,
#  5,
#  14,
#  23,
#  19,
#  13,
#  11,
#  24,
#  3,
#  20,
#  15,
#  0,
#  10,
#  4,
#  16,
#  1,
#  2,
#  9]

# %%
keys = sorted(keys, key=lambda x: keys.count(x), reverse=True)

# %%
keys
# Out:
# [10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  1,
#  14,
#  5,
#  19,
#  1,
#  19,
#  4,
#  4,
#  5,
#  19,
#  14,
#  4,
#  1,
#  5,
#  14,
#  1,
#  19,
#  4,
#  5,
#  1,
#  19,
#  4,
#  14,
#  5,
#  1,
#  19,
#  5,
#  14,
#  19,
#  4,
#  4,
#  5,
#  1,
#  4,
#  5,
#  1,
#  19,
#  5,
#  1,
#  14,
#  19,
#  4,
#  14,
#  19,
#  4,
#  5,
#  1,
#  14,
#  5,
#  1,
#  14,
#  19,
#  1,
#  14,
#  4,
#  4,
#  1,
#  14,
#  19,
#  5,
#  5,
#  14,
#  4,
#  1,
#  19,
#  14,
#  5,
#  19,
#  1,
#  5,
#  14,
#  4,
#  14,
#  19,
#  5,
#  4,
#  4,
#  19,
#  14,
#  1,
#  5,
#  14,
#  19,
#  4,
#  1,
#  6,
#  18,
#  3,
#  3,
#  23,
#  6,
#  3,
#  6,
#  23,
#  18,
#  3,
#  18,
#  23,
#  6,
#  23,
#  18,
#  3,
#  6,
#  3,
#  6,
#  3,
#  18,
#  23,
#  6,
#  23,
#  18,
#  23,
#  6,
#  3,
#  18,
#  6,
#  3,
#  23,
#  23,
#  6,
#  18,
#  6,
#  23,
#  3,
#  6,
#  3,
#  18,
#  23,
#  3,
#  6,
#  18,
#  6,
#  18,
#  23,
#  6,
#  3,
#  18,
#  18,
#  23,
#  3,
#  18,
#  6,
#  23,
#  18,
#  23,
#  3,
#  18,
#  23,
#  3,
#  9,
#  8,
#  17,
#  21,
#  2,
#  22,
#  21,
#  17,
#  2,
#  21,
#  8,
#  17,
#  22,
#  22,
#  9,
#  17,
#  2,
#  8,
#  2,
#  8,
#  9,
#  21,
#  2,
#  17,
#  9,
#  21,
#  22,
#  8,
#  21,
#  22,
#  17,
#  8,
#  9,
#  22,
#  21,
#  2,
#  8,
#  9,
#  17,
#  2,
#  22,
#  9,
#  2,
#  21,
#  8,
#  8,
#  17,
#  9,
#  22,
#  2,
#  21,
#  9,
#  2,
#  17,
#  22,
#  2,
#  17,
#  8,
#  8,
#  21,
#  9,
#  17,
#  9,
#  22,
#  2,
#  17,
#  21,
#  21,
#  2,
#  22,
#  8,
#  8,
#  17,
#  9,
#  21,
#  22,
#  17,
#  9,
#  8,
#  21,
#  22,
#  21,
#  17,
#  22,
#  2,
#  9,
#  8,
#  22,
#  2,
#  9,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  25,
#  25,
#  0,
#  13,
#  0,
#  13,
#  25,
#  25,
#  0,
#  25,
#  0,
#  0,
#  13,
#  13,
#  25,
#  13,
#  25,
#  0,
#  0,
#  25,
#  13,
#  0,
#  13,
#  25,
#  13,
#  0,
#  25,
#  13,
#  0,
#  25,
#  13,
#  13,
#  0,
#  25,
#  13,
#  25,
#  0,
#  13,
#  0,
#  24,
#  20,
#  12,
#  16,
#  11,
#  16,
#  7,
#  12,
#  7,
#  24,
#  20,
#  24,
#  16,
#  20,
#  7,
#  24,
#  11,
#  20,
#  16,
#  7,
#  12,
#  20,
#  7,
#  11,
#  16,
#  11,
#  12,
#  24,
#  20,
#  7,
#  12,
#  24,
#  11,
#  24,
#  7,
#  20,
#  11,
#  12,
#  12,
#  16,
#  24,
#  11,
#  16,
#  7,
#  11,
#  7,
#  12,
#  24,
#  16,
#  12,
#  16,
#  20,
#  20,
#  11,
#  7,
#  11,
#  16,
#  12,
#  7,
#  20,
#  16,
#  12,
#  7,
#  20,
#  24,
#  24,
#  11,
#  12,
#  11,
#  24,
#  20,
#  16]

# %%
print(keys[0])
# Out:
# 10
